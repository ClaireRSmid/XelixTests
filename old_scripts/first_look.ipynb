# %% [markdown]
# # The Data

# %% [markdown]
# ## Basic imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Connecting to the database
#
# Setting up a connection to the database file is straightforward via `sqlite`. Just update the location of the data file and you're connected!

# %%
f_data = "email_extractor.sqlite"

# %%
import sqlite3

# %%
con = sqlite3.connect(f_data)

# %% [markdown]
# The important parts of the database look like:
#
# ![database structure](./images/email_extractor_db_diagram.png "Database Structure")
#
# There are other tables as well, but they're all around admin/permissions so shouldn't be relevant.

# %% [markdown]
# ## Reading from the database
#
# You can use `pandas` to read raw SQL queries using the connection that we have just made. For example, if we want to look at all of the tables in the database:

# %%
pd.read_sql_query("SELECT * FROM sqlite_master WHERE type='table'", con)
# Out:
#      type                                 name  \
# 0   table                        accounts_user
# 1   table                 accounts_user_groups
# 2   table       accounts_user_user_permissions
# 3   table                           auth_group
# 4   table               auth_group_permissions
# 5   table                      auth_permission
# 6   table                     django_admin_log
# 7   table   django_celery_beat_clockedschedule
# 8   table   django_celery_beat_crontabschedule
# 9   table  django_celery_beat_intervalschedule
# 10  table      django_celery_beat_periodictask
# 11  table     django_celery_beat_periodictasks
# 12  table     django_celery_beat_solarschedule
# 13  table   django_celery_results_chordcounter
# 14  table    django_celery_results_groupresult
# 15  table     django_celery_results_taskresult
# 16  table                  django_content_type
# 17  table                    django_migrations
# 18  table                       django_session
# 19  table                      emails_category
# 20  table                         emails_email
# 21  table               emails_emailattachment
# 22  table                 emails_emailcategory
# 23  table               emails_emailsfetchedat
# 24  table                        emails_folder
# 25  table                  emails_imapsettings
# 26  table        emails_microsoftgraphsettings
# 27  table           organisations_organisation
#
#                                tbl_name  rootpage  \
# 0                         accounts_user         2
# 1                  accounts_user_groups         3
# 2        accounts_user_user_permissions         4
# 3                            auth_group         5
# 4                auth_group_permissions         6
# 5                       auth_permission         7
# 6                      django_admin_log         8
# 7    django_celery_beat_clockedschedule         9
# 8    django_celery_beat_crontabschedule        10
# 9   django_celery_beat_intervalschedule        11
# 10      django_celery_beat_periodictask        12
# 11     django_celery_beat_periodictasks        13
# 12     django_celery_beat_solarschedule        16
# 13   django_celery_results_chordcounter        17
# 14    django_celery_results_groupresult        18
# 15     django_celery_results_taskresult        19
# 16                  django_content_type        20
# 17                    django_migrations        21
# 18                       django_session        22
# 19                      emails_category        23
# 20                         emails_email        24
# 21               emails_emailattachment        25
# 22                 emails_emailcategory        26
# 23               emails_emailsfetchedat        28
# 24                        emails_folder        29
# 25                  emails_imapsettings        30
# 26        emails_microsoftgraphsettings        31
# 27           organisations_organisation        32
#
#                                                   sql
# 0   CREATE TABLE accounts_user (\n    id bigint NO...
# 1   CREATE TABLE accounts_user_groups (\n    id bi...
# 2   CREATE TABLE accounts_user_user_permissions (\...
# 3   CREATE TABLE auth_group (\n    id integer NOT ...
# 4   CREATE TABLE auth_group_permissions (\n    id ...
# 5   CREATE TABLE auth_permission (\n    id integer...
# 6   CREATE TABLE django_admin_log (\n    id intege...
# 7   CREATE TABLE django_celery_beat_clockedschedul...
# 8   CREATE TABLE django_celery_beat_crontabschedul...
# 9   CREATE TABLE django_celery_beat_intervalschedu...
# 10  CREATE TABLE django_celery_beat_periodictask (...
# 11  CREATE TABLE django_celery_beat_periodictasks ...
# 12  CREATE TABLE django_celery_beat_solarschedule ...
# 13  CREATE TABLE django_celery_results_chordcounte...
# 14  CREATE TABLE django_celery_results_groupresult...
# 15  CREATE TABLE django_celery_results_taskresult ...
# 16  CREATE TABLE django_content_type (\n    id int...
# 17  CREATE TABLE django_migrations (\n    id bigin...
# 18  CREATE TABLE django_session (\n    session_key...
# 19  CREATE TABLE emails_category (\n    id bigint ...
# 20  CREATE TABLE emails_email (\n    id bigint NOT...
# 21  CREATE TABLE emails_emailattachment (\n    id ...
# 22  CREATE TABLE emails_emailcategory (\n    id bi...
# 23  CREATE TABLE emails_emailsfetchedat (\n    id ...
# 24  CREATE TABLE emails_folder (\n    id bigint NO...
# 25  CREATE TABLE emails_imapsettings (\n    id big...
# 26  CREATE TABLE emails_microsoftgraphsettings (\n...
# 27  CREATE TABLE organisations_organisation (\n   ...

# %% [markdown]
# ## Accessing emails
#
# The emails themselves are in the `emails_email` table. There's lots of fields, but the key ones are:
#
# - `id`: unique integer identifier for the email
# - `internal_date`: the date of the email (`created_at` and `updated_at` are dates relating to the database records)
# - `from_address`: the sender of the email
# - `html_body`: the email body in html format (see below)
# - `plain_text_body`: the email body in plain text format (see below)
# - `subject`: the subject of the email
# - `to`: the set of addresses that the email was sent to
# - `eml_file`: the location of the email file

# %%
df = pd.read_sql_query("SELECT * FROM emails_email LIMIT 50000", con)

# %%
df.head()
# Out:
#        id                     created_at                     updated_at  \
# 0  306340  2022-07-29 20:00:12.363819+00  2022-07-29 20:00:12.363835+00
# 1  306341  2022-07-29 20:00:12.927732+00  2022-07-29 20:00:12.927749+00
# 2  306342  2022-07-29 20:00:13.208991+00  2022-07-29 20:00:13.209005+00
# 3  306343  2022-07-29 20:00:13.423754+00  2022-07-29 20:00:13.423769+00
# 4  306344  2022-07-29 20:00:13.606982+00  2022-07-29 20:00:13.606995+00
#
#       uid    flags           internal_date bcc  cc            from_address  \
# 0  8464.0  \Recent  2022-07-28 22:31:54+00  {}  {}      no-reply@avery.com
# 1  8465.0  \Recent  2022-07-28 22:32:29+00  {}  {}      no-reply@avery.com
# 2  8466.0  \Recent  2022-07-28 22:33:27+00  {}  {}      no-reply@avery.com
# 3  8467.0  \Recent  2022-07-28 22:37:12+00  {}  {}      no-reply@avery.com
# 4  8468.0  \Recent  2022-07-29 09:41:28+00  {}  {}  info@phoenixsafe.co.uk
#
#                                            html_body  \
# 0  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 1  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 2  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 3  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 T...
# 4  <!doctype html><html xmlns="http://www.w3.org/...
#
#                                           message_id  \
# 0         <202207282230.26SMUf7A003811@mail.qad.com>
# 1         <202207282231.26SMV1Le003938@mail.qad.com>
# 2         <202207282231.26SMVa9Q004201@mail.qad.com>
# 3         <202207282231.26SMV7cM004046@mail.qad.com>
# 4  <c2e1bcff24eed0dbef1ffd4a0.910c7a73bb.20220729...
#
#                                      plain_text_body  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  Attention: This email originated outside of ou...
#
#                    reply_to             subject  \
# 0                        {}  Avery UK Invoice:
# 1                        {}  Avery UK Invoice:
# 2                        {}  Avery UK Invoice:
# 3                        {}  Avery UK Invoice:
# 4  {info@phoenixsafe.co.uk}      Keep Cash Safe
#
#                                   to  \
# 0  {purchase.ledger@evo-group.co.uk}
# 1  {purchase.ledger@evo-group.co.uk}
# 2  {purchase.ledger@evo-group.co.uk}
# 3  {purchase.ledger@evo-group.co.uk}
# 4  {purchase.ledger@evo-group.co.uk}
#
#                                             eml_file  folder_id
# 0  email_data/Evo Group/bbbf78a5-ccf2-44dd-af99-2...          3
# 1  email_data/Evo Group/cb06c705-4beb-44d6-86db-d...          3
# 2  email_data/Evo Group/a9c0843e-e907-4013-b742-d...          3
# 3  email_data/Evo Group/8216b595-d169-4521-89ee-3...          3
# 4  email_data/Evo Group/f467154d-fbb3-44cd-96cd-0...          3

# %% [markdown]
# ## Email bodies
#
# Email bodies can be stored in `html` format, `plain_text` format or both.

# %%
w_html = df.html_body.notnull() 
w_plain = df.plain_text_body.notnull()

# %%
w_html.sum()
# Out:
# 38931

# %%
w_plain.sum()
# Out:
# 17462

# %%
(w_html & w_plain).sum()
# Out:
# 6399

# %% [markdown]
# Below is a method that we have used previously to convert html format bodies to text. The package `html2text` could also be used for this it seems.

# %%
from bs4 import BeautifulSoup, Comment

def text_from_html(body) -> str:
    if pd.isnull(body):
        return ""

    def tag_visible(element):
        if element.parent.name in ["style", "script", "head", "title", "meta", "[document]"]:
            return False
        if isinstance(element, Comment):
            return False
        return True

    soup = BeautifulSoup(body, "html.parser")
    texts = soup.findAll(string=True)
    visible_texts = filter(tag_visible, texts)
    return " ".join(t.strip() for t in visible_texts)

# import html2text
# html2text.html2text(text)

# %%
# def text_from_html(body: str | None) -> str:
#     if pd.isnull(body):
#         return ""

# %%
df["html_body_as_text"] = df["html_body"].map(text_from_html)

# %%
df["body"] = df["plain_text_body"]

# %%
df.loc[df["body"].isnull(), "body"] = df.loc[df["body"].isnull(), "html_body_as_text"]

# %%
df["body"].isnull().value_counts()
# Out:
# False    50000
# Name: body, dtype: int64

# %% [markdown]
# ## Accessing email categorisations
#
# The email categories are stored in `emails_category`. This then links to the emails themselves via the `emails_emailcategory` table.
#
# Here, data from the three tables is pulled separately, but you can of course join the data in an SQL query.

# %%
df_email_categorisations = pd.read_sql_query("SELECT * FROM emails_emailcategory", con)

# %%
df_email_categorisations.head()
# Out:
#       id                     created_at                     updated_at  \
# 0  12264  2022-07-26 09:30:40.505263+00  2022-07-26 09:30:40.505285+00
# 1  12265  2022-07-26 09:30:40.505309+00  2022-07-26 09:30:40.505314+00
# 2  12266  2022-07-26 09:30:40.505325+00  2022-07-26 09:30:40.505329+00
# 3  12267   2022-07-26 09:30:40.50534+00  2022-07-26 09:30:40.505344+00
# 4  12268  2022-07-26 09:30:40.505355+00  2022-07-26 09:30:40.505359+00
#
#    category_id  created_by_id  email_id
# 0          101            NaN    284813
# 1          101            NaN    284821
# 2          101            NaN    285029
# 3          101            NaN    285515
# 4          101            NaN    285679

# %%
df_email_categories = pd.read_sql_query("SELECT * FROM emails_category", con)

# %% [markdown]
# One thing to note: for some reason the email categories table has duplicated entries:

# %%
df_email_categories.sort_values(by="name").head()
# Out:
#     id                     created_at                     updated_at  \
# 45  34  2022-07-25 11:13:26.881888+00  2022-07-26 14:55:38.134577+00
# 21  34  2022-07-25 11:13:26.881888+00  2022-07-26 14:55:38.134577+00
# 1   35  2022-07-25 11:14:09.036276+00  2022-07-25 11:14:09.036299+00
# 25  35  2022-07-25 11:14:09.036276+00  2022-07-25 11:14:09.036299+00
# 43  36  2022-07-25 11:14:38.218737+00  2022-07-26 09:58:01.408127+00
#
#                   name                slug hidden
# 45           Backorder           backorder      t
# 21           Backorder           backorder      t
# 1   Bank Detail Change  bank-detail-change      f
# 25  Bank Detail Change  bank-detail-change      f
# 43         Credit Note         credit-note      t

# %% [markdown]
# For now let's convert the categories table into a dictionary and map that to the categorisations table.

# %%
category_slug_lookup = df_email_categories.drop_duplicates(keep="first", subset=["id", "name"]).set_index("id")["slug"].to_dict()
df_email_categorisations["category_slug"] = df_email_categorisations["category_id"].map(category_slug_lookup)

# %%
df_email_categorisations.head()
# Out:
#       id                     created_at                     updated_at  \
# 0  12264  2022-07-26 09:30:40.505263+00  2022-07-26 09:30:40.505285+00
# 1  12265  2022-07-26 09:30:40.505309+00  2022-07-26 09:30:40.505314+00
# 2  12266  2022-07-26 09:30:40.505325+00  2022-07-26 09:30:40.505329+00
# 3  12267   2022-07-26 09:30:40.50534+00  2022-07-26 09:30:40.505344+00
# 4  12268  2022-07-26 09:30:40.505355+00  2022-07-26 09:30:40.505359+00
#
#    category_id  created_by_id  email_id category_slug
# 0          101            NaN    284813     reminders
# 1          101            NaN    284821     reminders
# 2          101            NaN    285029     reminders
# 3          101            NaN    285515     reminders
# 4          101            NaN    285679     reminders

# %% [markdown]
# We can then pull out the change-of-bank-details emails, and look at a few examples. Note, there's not many examples in our dataframe because:
# 1. Only ~1% of emails have been categorised
# 2. We only pulled ~3% of emails to start with

# %%
df_bdc = df_email_categorisations[df_email_categorisations["category_slug"] == "bank-detail-change"]
df_bdc.head()
# Out:
#       id                     created_at                     updated_at  \
# 679  906  2022-07-25 11:14:12.838098+00  2022-07-25 11:14:12.838116+00
# 680  907  2022-07-25 11:14:12.838137+00  2022-07-25 11:14:12.838142+00
# 681  908  2022-07-25 11:14:12.838153+00  2022-07-25 11:14:12.838157+00
# 682  909  2022-07-25 11:14:12.838168+00  2022-07-25 11:14:12.838172+00
# 683  910  2022-07-25 11:14:12.838183+00  2022-07-25 11:14:12.838187+00
#
#      category_id  created_by_id  email_id       category_slug
# 679           35            NaN    282436  bank-detail-change
# 680           35            NaN    283345  bank-detail-change
# 681           35            NaN    290334  bank-detail-change
# 682           35            NaN    290391  bank-detail-change
# 683           35            NaN    291518  bank-detail-change

# %%
df[df.id.isin(df_bdc["email_id"])]
# Out:
#            id                     created_at                     updated_at  \
# 8535   186977  2022-07-20 17:10:52.857914+00  2022-08-19 08:59:21.724909+00
# 25926  186977  2022-07-20 17:10:52.857914+00  2022-08-19 08:59:21.724909+00
#
#             uid  flags           internal_date bcc  \
# 8535   390141.0  \Seen  2021-09-14 10:07:55+00  {}
# 25926  390141.0  \Seen  2021-09-14 10:07:55+00  {}
#
#                                                       cc  \
# 8535   {Purchase.Ledger@evo-group.co.uk,Alex.Mackay@b...
# 25926  {Purchase.Ledger@evo-group.co.uk,Alex.Mackay@b...
#
#                           from_address  \
# 8535   mina.pasaloglou@evo-group.co.uk
# 25926  mina.pasaloglou@evo-group.co.uk
#
#                                                html_body  \
# 8535   <html xmlns:v="urn:schemas-microsoft-com:vml" ...
# 25926  <html xmlns:v="urn:schemas-microsoft-com:vml" ...
#
#                                               message_id plain_text_body  \
# 8535   <LO4P265MB3613B656540D7DB92FEAFA90F2DA9@LO4P26...            None
# 25926  <LO4P265MB3613B656540D7DB92FEAFA90F2DA9@LO4P26...            None
#
#       reply_to                           subject  \
# 8535        {}  RE: Tyronex Bank Account Change
# 25926       {}  RE: Tyronex Bank Account Change
#
#                                                       to  \
# 8535   {Matt@tyronex.co.uk,Matt.Hales@evo-group.co.uk...
# 25926  {Matt@tyronex.co.uk,Matt.Hales@evo-group.co.uk...
#
#                                                 eml_file  folder_id  \
# 8535   email_data/Evo Group/d2216e54-60dc-45b6-8120-8...          6
# 25926  email_data/Evo Group/d2216e54-60dc-45b6-8120-8...          6
#
#                                        html_body_as_text  \
# 8535       Hi Matt,    Thank you for your email. Can ...
# 25926      Hi Matt,    Thank you for your email. Can ...
#
#                                                     body
# 8535       Hi Matt,    Thank you for your email. Can ...
# 25926      Hi Matt,    Thank you for your email. Can ...

# %%
for row in df[df.id.isin(df_bdc["email_id"])].head(10).itertuples():
    print("#" * 80, "\n\n")
    print("SUBJECT:\n",row.subject)
    print("")
    print("BODY:\n",row.body)
    print("\n")
# Out:
# ################################################################################
#
#
# SUBJECT:
#  RE: Tyronex Bank Account Change
#
# BODY:
#      Hi Matt,    Thank you for your email. Can you also please provide one of the following:    -Void cheque  -Void payment slip  -A bank statement    Thank you,  Mina      From: Matt Tibble <Matt@tyronex.co.uk>  Sent: 13 September 2021 10:17  To: Matt Hales <Matt.Hales@evo-group.co.uk>; Robert Mitchell <Robert.Mitchell@banneruk.com>  Cc: Purchase Ledger <Purchase.Ledger@evo-group.co.uk>; Alex Mackay <Alex.Mackay@banneruk.com>; Mina Pasaloglou <mina.pasaloglou@evo-group.co.uk>; Accounts <accounts@tyronex.co.uk>  Subject: FW: Tyronex Bank Account Change      Alert: There is currently a serious threat from opening email attachments. If you have any concerns about an attached file please contact IT.  Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.   Hi All    Apologies, please find attached the correct bank account details (sterling account).    Please confirm that these have been amended on your supplier account details.    Kind regards    Matt     Matthew Tibble | Senior Account Manager | E: matt@tyronex.co.uk  DDI:  0203 889 1565 T: 0203 889 1560 | M: 07305 059 553 | Skype : live:mte2019            From: Matt Tibble  Sent: 13 September 2021 09:49  To: Matt Hales < Matt.Hales@evo-group.co.uk >; Robert Mitchell < Robert.Mitchell@banneruk.com >  Cc:  purchase.ledger@evo-group.co.uk ; Alex Mackay < Alex.Mackay@banneruk.com >; Mina Pasaloglou < mina.pasaloglou@evo-group.co.uk >;
#  Accounts < accounts@tyronex.co.uk >  Subject: Tyronex Bank Account Change      Hi All    Please find attached our new bank account details.    Please confirm that these have been amended on your supplier account details.    Kind regards    Matt    Matthew Tibble | Senior Account Manager | E: matt@tyronex.co.uk  DDI:  0203 889 1565 T: 0203 889 1560 | M: 07305 059 553 | Skype : live:mte2019
#
#
# ################################################################################
#
#
# SUBJECT:
#  RE: Tyronex Bank Account Change
#
# BODY:
#      Hi Matt,    Thank you for your email. Can you also please provide one of the following:    -Void cheque  -Void payment slip  -A bank statement    Thank you,  Mina      From: Matt Tibble <Matt@tyronex.co.uk>  Sent: 13 September 2021 10:17  To: Matt Hales <Matt.Hales@evo-group.co.uk>; Robert Mitchell <Robert.Mitchell@banneruk.com>  Cc: Purchase Ledger <Purchase.Ledger@evo-group.co.uk>; Alex Mackay <Alex.Mackay@banneruk.com>; Mina Pasaloglou <mina.pasaloglou@evo-group.co.uk>; Accounts <accounts@tyronex.co.uk>  Subject: FW: Tyronex Bank Account Change      Alert: There is currently a serious threat from opening email attachments. If you have any concerns about an attached file please contact IT.  Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.   Hi All    Apologies, please find attached the correct bank account details (sterling account).    Please confirm that these have been amended on your supplier account details.    Kind regards    Matt     Matthew Tibble | Senior Account Manager | E: matt@tyronex.co.uk  DDI:  0203 889 1565 T: 0203 889 1560 | M: 07305 059 553 | Skype : live:mte2019            From: Matt Tibble  Sent: 13 September 2021 09:49  To: Matt Hales < Matt.Hales@evo-group.co.uk >; Robert Mitchell < Robert.Mitchell@banneruk.com >  Cc:  purchase.ledger@evo-group.co.uk ; Alex Mackay < Alex.Mackay@banneruk.com >; Mina Pasaloglou < mina.pasaloglou@evo-group.co.uk >;
#  Accounts < accounts@tyronex.co.uk >  Subject: Tyronex Bank Account Change      Hi All    Please find attached our new bank account details.    Please confirm that these have been amended on your supplier account details.    Kind regards    Matt    Matthew Tibble | Senior Account Manager | E: matt@tyronex.co.uk  DDI:  0203 889 1565 T: 0203 889 1560 | M: 07305 059 553 | Skype : live:mte2019

# %% [markdown]
# Doing a quick keyword search for "bank details" shows that most emails containing this phrase aren't *change* of bank details emails.

# %%
for row in df[df.plain_text_body.str.contains("bank details") == True].head(10).itertuples():
    print("#" * 80, "\n\n")
    print(row.subject)
    print("")
    print(row.body)
    print("\n")
# Out:
# ################################################################################
#
#
# RE: **URGENT** Invoice for services - attached (ref. 25443)
#  (#0773545)
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# -#-#- Please reply above this line -#-#-
#
# ________________________________
# Chris Ridgeon
# 29/07/2022 11:37 AM
#
#
# Good afternoon,
#
#
#
# This is now urgent.
#
#
#
# Please can we chase the attached invoice for payment, it is overdue and was issued in May.
#
#
#
# Thanks,
#
# Chris Ridgeon
# Ridgeon Network Support
# Office: 02476 382031
#
# ________________________________
# Chris Ridgeon
# 19/07/2022 11:00 AM
#
#
# Good morning,
#
#
#
# Please can we have a payment date for the attached overdue invoice?
#
#
#
# Thanks,
#
# Chris Ridgeon
# Ridgeon Network Support
# Office: 02476 382031
#
# ________________________________
# accounts@ridgeon-network.co.uk
# 31/05/2022 11:46 AM
#
#
# [Ridgeon Network Ltd]<http://www.ridgeon-network.co.uk/>
#
# Ridgeon Network Ltd – Accounts – Invoice Attached
# Vow Europe Ltd.
# Please find attached the invoice for your Ridgeon Network services / renewals.
# If you could pass this to your Accounts Payable department for payment, it would be greatly appreciated.
# [Adobe PDF icon]
# Please see attached for a copy of your invoice.
# If you require any further details or have any questions, please do not hesitate to contact us. Your Ridgeon Network Direct Contact details are shown below.
#
#
# Invoice Overview
#
# Invoice #: 25443 Date: 31/05/2022 Amount Due: £1,844.40
#
#
# Payment Options
#
# BACS / Cheque Payment- Details for payment including bank details can be found on the footer of the invoice.
#
# Credit / Debit Card Payment- you can pay this invoice online using a credit/debit card easily at www.ridgeon-network.co.uk/pay<http://www.ridgeon-network.co.uk/pay>.
#
# Direct Debit Payment– If you are already set up for Direct Debit with us, you do not need to do anything. Payments are collected on 15th of each month. If you are not using Direct Debit but would like to, please feel free to give us a call on 02476 382031 or visit
# www.ridgeon-network.co.uk/directdebit<http://www.ridgeon-network.co.uk/directdebit>.
#
# Your Ridgeon Network Direct Contact Details
#
# Chris Ridgeon
# Ridgeon Network Ltd
# Email: chris@ridgeonnet.com<mailto:chris@ridgeonnet.com>
# Office: 02476 382031
# Mobile: 0779 500 6337
# Thank you for your business.
#
#
# ________________________________
# Ticket #: 0773545
# Subject: **URGENT** Invoice for services - attached (ref. 25443)
#
# Kind Regards,
# Ridgeon Network
#
#
#
# ################################################################################
#
#
# REDBOX: Sales Invoice (00613567)
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Please find attached your Invoice(s) 00613567
#
# Thank you for your business.
#
# Please note our bank details - Bank - Barclays Bank Plc, Account - 73882306, Sort Code - 20-00-00.
#
# If you have any queries regarding this Invoice please contact our Accounts Department on finance@redbox.co.uk or 0203 328 6002.
#
#
#
# Regards REDBOX
#
# Redbox Finance​
# [cid:image561774.png@1F752A6F.4A54291D]
# T:      0203 328 6002<tel:0203%20328%206002>
# E:
# finance@redbox.co.uk<mailto:finance@redbox.co.uk>
#
# Unit E3 | Brooklands Close
# ​Sunbury‑On‑Thames | TW16 7EB
# www.redbox.co.uk<http://www.redbox.co.uk/>
# [LinkedIn]<https://www.linkedin.com/company/red-box>
# [Twitter]<https://twitter.com/REDBOX_office>
# [cid:image234316.jpg@8EFEC6A8.C8CE81A3]<http://www.redboxonline.co.uk/>
# Ask me about our
# [cid:image151279.png@8D8D06A4.A90AF4ED]<https://red2.green/>
# initiative today
# [cid:image488955.jpg@1793063C.0467343F]<https://redbox.co.uk/bcorp/>
# Confidential and privileged information may be contained in this email: any unauthorised access, storing, disclosure, copying, distribution or other use is prohibited. If you are not the person indicated in this message, or their authorised agent, please notify the sender by return email and kindly delete this message from your system. As Internet communications are not fully secure, OfficeBASE Group does not accept legal responsibility for the contents of this email or any attachment.
#
# ﻿OfficeBASE Limited trading as REDBOX. Registered in England No. 02218322
# Registered Office: Upper Deck, Admirals Quarters, Portsmouth Road, Thames Ditton, Surrey KT7 0XA
#
#
#
# ################################################################################
#
#
# Outstanding Invoice
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Good Afternoon,
#
# I hope my email finds you well?
#
# Could you please provide a payment date for the above invoice which is now outstanding
# Please refer to this for bank details
#
# I look forward to receiving your payment in due course
#
#
# Regards
# Credit Control
#
#
#
# [cid:image001.png@01D8A689.C1BB7D50]
#
# Collins Debden Ltd
# Suite 314, 9 George Square, Glasgow, United Kingdom, G2 1QQ
# www.collinsdebden.com<http://www.collinsdebden.com/>
#
# [cid:image002.png@01D8A689.C1BB7D50]<https://www.facebook.com/CollinsDebden>[cid:image003.png@01D8A689.C1BB7D50]<https://twitter.com/collinsdiaries> [cid:image004.png@01D8A689.C1BB7D50] <https://www.instagram.com/collinsdebden/>  [https://2rvq6i2ijzas17wg5g2ddc71-wpengine.netdna-ssl.com/wp-content/themes/xink/assets/images/icons/color/32/linkedin_001.png] <https://www.linkedin.com/company/collins-debden>  [cid:image006.png@01D8A689.C1BB7D50] <https://www.youtube.com/channel/UCCwUboKEIa3Lc7XZgPcaHTA>
#
#
#
#
# ################################################################################
#
#
# Invoice 208709
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Please find attached your invoice/s. Should you have any invoice queries, please email accounts@abacus-employment.com or call on 01635 569579.
#
#
#
#
#
# Our bank details are HSBC  Sort code 40-61-35, Account no. 03008268
#
# Should you have any further queries please do not to hesitate to contact us
#
#
#
# ################################################################################
#
#
# Invoices from EET UK
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Dear VOW Europe,
#
# Please find attached our invoices/credit notes dated 03-08-22.
#
# For speed and ease our preferred method of payment is by bank transfer.
#
# Our bank details are:
#
# Nordea Bank Finland PLC
#
# Citibank N.A. London Branch.
# IBAN: GB85CITI18500814416279
# SWIFT: CITIGB2L
# Bank Account No.: 14416279, Sort Code: 185008
# EUR:IE40CITI99005100100625, SWIFT:CITIIE2X
# Please quote your company name and invoice number.
#
# Please note we no longer accept payment by cheque.
#
# If you have already paid by credit/debit card, please disregard the above.
#
# Kind regards,
#
# EET UK
#
# Tel: +44 (0) 333 241 9251
# Email: finance@eeteuroparts.co.uk
#
# Invoice No.     Order no.       Requisition No.         Total incl. vat.
# 3779565         2782531         987600  209,94 GBP
#
#
#
#
# ################################################################################
#
#
# Overdue Account
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
# Good afternoon
#
# We have attached your latest statement. Your account is now overdue and is on hold.
#
# Details of the outstanding invoices that are beyond our agreed payment terms are listed on the attached statement.
#
# Please arrange payment by return.
#
#
# Many thanks
# Christine Bennett
# Credit Control
#
# ArtSystems | Unit 10-12 Glaisdale Point | Glaisdale Parkway | Nottingham. NG8 4GP
# creditcontrol@artsystems.co.uk |<mailto:creditcontrol@artsystems.co.uk%20%7C> tel 0115 9380 380 |ddi 0115 9380 340
#
# Should you receive an email notifying you of any changes to our bank details  we ask that you do not respond and to call your  direct contact at Art Systems for verification.
#
# Art Systems have not changed their bank details.
#
# Thank you for your understanding.
#
#
#
#
#
# [Logo]
#
# ____________________________________________________________________
#
# Any views or opinions presented in this email are solely those of the author and do not necessarily represent those of the company. Employees of Art Systems Limited are expressly required not to make defamatory statements and not to infringe or authorise any infringement of copyright or any other legal right by email communications. Any such communication is contrary to company policy and outside the scope of the employment of the individual concerned. The company will not accept any liability in respect of such communication, and the employee responsible will be personally liable for any damages or other liability arising. This message (including any file attachment) contains confidential information and is intended only for the stated recipient. If you are not the named addressee you should not disseminate, distribute, or copy this e-mail. Please notify the sender immediately by e-mail if you have received this e-mail by mistake and delete this e-mail from your system. Although all outgoing emails have been checked for viruses, we do not accept liability for any damage you sustain because of a virus. All outgoing and incoming emails to and from Art Systems Limited are monitored and senders of messages shall be taken to consent to the monitoring and recording of emails addressed to our employees. Art Systems Limited is registered in England and Wales (registered no. 03079342). Registered Office: Unit 10-12 Glaisdale Point, Glaisdale Parkway, Nottingham NG8 4GP
#
#
#
# ################################################################################
#
#
# Overdue invoices
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
# Hi
#
# Please find enclosed your up to date statement as of today.
#
# As you can see there is £8,640 worth of invoices now overdue.
#
# Our bank details did change in April, so I am wondering if you have made a payment into our old account which hasn't been allocated?
#
# Alternatively, if payment hasn't been made, please can you advise if the invoices are in query?
#
# Please let me know ASAP.
#
# Thanks
# Kirsty
#
#
#
#
# ################################################################################
#
#
# Remittance
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
# Good Afternoon
#
# Can I please get a remittance for your payment of £607.68 on 02/08/22?
#
# Many thanks
#
# Paul
# [cid:image047392.png@1F9470B5.B93F401D]
# Paul Whibberley​         |
# Credit Controller/Sales Ledger Clerk
# T: 0114 272 8888
# E: Paul.Whibberley@precisionproco.co.uk<mailto:Paul.Whibberley@precisionproco.co.uk>
# Precision Proco, Parkway Close, Parkway Industrial Estate, Sheffield, S9 4WJ
# Precision Proco is a trading name of Proco Print Limited, incorporated and registered in England and Wales with company number 03378837 whose registered office is at Parkway Close , Parkway Industrial Estate , Sheffield S9 4WJ.
# precisionproco.co.uk<https://precisionproco.co.uk/>
# [cid:image993496.png@55F6F1BD.8534686F]<https://www.facebook.com/PrecisionProco>
# [cid:image728609.png@BABCB997.6508C046]<https://twitter.com/PrecisionProco>
# [cid:image893834.png@3C8E7942.47012740]<https://www.instagram.com/precisionproco/>
# [cid:image722350.png@0279BDD3.1A1D30B9]<https://www.linkedin.com/company/precisionproco/>
# The world has changed, so have we.
# Our group of companies:
# ​
# [cid:image950865.png@7B680C16.1F764032]<https://precisionproco.co.uk/>  [cid:image521243.png@3E1B0FDB.51336504] <https://www.primegroup.co.uk/>         [cid:image608423.png@DE882D90.F0FD85F3] <https://climbcreative.co.uk/>  [cid:image981720.png@2EE31D15.153534F2] <https://www.wherethetradebuys.co.uk/>
# CYBERCRIME ALERT: Please be aware of the increase in cybercrime and fraud.
# ​If you receive an email purporting to be from someone at Precision Proco Group which seems suspicious, or seeks to direct a payment to bank details which differ from those which we have already given to you, it is unlikely to be genuine.
# ​Please do not reply to the email or act on any information contained in it but contact the company directly, preferable via a phone call.
#
#
#
# ################################################################################
#
#
# VOW EUROPE LTD - 61155
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
# Hello Lisa,
#
# Please check on the below statement of account and kindly confirm back with the payment status for the overdue invoice.
#
# Customer ID
# CW1 AccountNr.
# Type
# Invoice
# Salesorder
# Doc Date
# Collection Trigger Date
# Curr.
# Trans.Amount
# Trans.Bal.Due
# Base Amount
# Base Bal.Due
# DBT
# 61155
# GBVOE001
# IN
# H1001064
# SZXB64805
# 17-06-2022
# 17-07-2022
# GBP
# 2,550.95
# 2,550.95
# 2,550.95
# 2,550.95
# 19
#
#
# Thanks & Regards,
# Jagan
# Credit Controller
# Tel    - +44 203 901 3951
# Extn -  7100249
#
# Jagan.mari@dhl.com<mailto:Jagan.mari@dhl.com>
# www.dhl.com<http://www.dhl.com/>
#
# DHL Global Forwarding Freight Shared Services (India) LLP
# 9th Floor | North Block |Tower B | Chennai One IT SEZ
# Pallavaram | Thoraipakkam 200ft. Road | Thoraipakkam
# Chennai 600097| Tamilnadu | India
# [cid:image001.png@01D8A8E2.EE302EC0]
#
# Kindly see our escalation matrix below:
#
# Escalation Level
# Name
# Designation
# Toll Free
# Email ID
# Level 1
# Nisha Karthickraja
# Team Leader
# +44 203 901 3951
# nisha.karthickraja@dhl.com<mailto:nisha.karthickraja@dhl.com>
# Level 2
# Ramakrishnan Kalpathi Lakshminarayanan
# Manager
#
# Ramakrishnan.KalpathiLakshminarayanan@dhl.com<mailto:Ramakrishnan.KalpathiLakshminarayanan@dhl.com>
#
# Please forward all your future remittances to DGF.GB.CashApplication@dhl.com<mailto:DGF.GB.CashApplication@dhl.com> to help us post your payments without further delay.
#
# PLEASE NOTE OF REMITTANCE ADDRESS:  DHL Global Forwarding (UK) Limited, Eastworth House, Eastworth Road, Chertsey, Surrey, KT16 8SH
#
#
# From: noreply@mx-ce-it-nl.dhl.com <noreply@mx-ce-it-nl.dhl.com> On Behalf Of jagan.mari@dhl.com
# Sent: 14 July 2022 10:00
# To: alicia.thorpe@evo-group.co.uk; lisa.dyson@vasantagroup.com; Purchase.ledger@evo-group.co.uk
# Cc: Jagan Mari (DHL IN), external <jagan.mari@dhl.com>; Nisha Karthickraja (DHL IN) <nisha.karthickraja@dhl.com>
# Subject: Invoice Overview - Account: 61155 - VOW EUROPE LTD
#
#
#
#
# VOW EUROPE LTD 14/07/2022
#
# SHEFFIELD AIRPORT BUSINESS PARK
#
# EUROPA LINK
#
# SHEFFIELD
#
# UNITED KINGDOM
#
#
#
# S9 1X U
#
#
#
#
#
#
#
# Account number: 61155
#
#
#
#
#
# Statement of Account
#
#
#
#
#
# Dear Sir/Madam,
#
#
#
# Please find details of your statement of account.
#
#
#
# If you have any queries or concerns regarding this statement, please contact your Collection Specialist as detailed below.
#
#
#
# If this is in order, please ensure payment is received by the specified due date.
#
#
#
# Please note our bank details listed below.
#
#
#
# GBP: HSBC IBAN: GB51MIDL40025041231464 BIC: MIDLGB22
#
# EUR: Bank of America IBAN: BE40685742301763 BIC: BOFABE3X
#
# USD: Bank of America IBAN: BE49685742302571 BIC: BOFABE3X
#
#
#
#
#
# Yours faithfully,
#
#
#
#
#
#
#
# Jagan Mari
#
#
#
# DHL Global Forwarding (UK) Ltd
#
#
#
#
#
# Main Number: +44 0 203 901 3951
#
# Email: jagan.mari@dhl.com<mailto:jagan.mari@dhl.com>
#
#
#
# ################################################################################
#
#
# RE: Bradford Leisure Exchange Car Park Passes
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Good afternoon
#
#
#
# Please find attached your Aug 22 invoice
#
#
#
# Outstanding payment for invoice P4478
#
#
# Kind Regards
#
# Darren Ambrose
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk>
# Permits Department​
# Horizon Parking Limited
# P:      01245 392 289<tel:01245%20392%20289>
# E:      permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>        |      W:      www.horizonparking.co.uk<http://www.horizonparking.co.uk>
# A:      Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
# From: Permits Department
# Sent: 07 July 2022 13:37
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk>; Purchase Ledger <purchase.ledger@evo-group.co.uk>
# Cc: Permits Department <permits@horizonparking.co.uk>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
# Good afternoon
#
#
#
# Please find attached your July 22 invoice
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 08 June 2022 12:11
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
# Good afternoon
#
#
#
# Please find attached your June 22 invoice
#
#
#
# Outstanding payment for invoice P4269
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 13 May 2022 13:11
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
# Can we have a response to the below email regarding invoice P4179, This invoice is for Aprils Parking.
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 10 May 2022 14:54
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
# Good Morning
#
#
#
# Please find attached your May 22 invoice
#
#
#
# Outstanding payment for invoice P4179
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 25 April 2022 14:01
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
# Good Afternoon
#
# Can someone come back to me regarding the below,
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 20 April 2022 13:15
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
# Good afternoon
#
# Please advise when the attached invoice P4074 will be settled?
#
# As we are on a 30day payment term and the attached invoice was sent on 09/03/2022 we should have seen payment by now?
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 11 April 2022 09:11
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
# Good Morning
#
#
#
# Please find attached your April 22 invoice
#
#
#
# Outstanding payment for invoice P4074
#
#
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 09 March 2022 09:49
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
# Good Morning
#
#
#
# Please find attached your Mar 22 invoice
#
#
#
# Outstanding payment for invoice P3986
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 01 March 2022 12:24
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; Purchase Ledger <purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
# Good Afternoon,
#
# Please advise when the attached invoice will be settled?
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 09 February 2022 10:23
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
# Good Morning
#
#
#
# Please find attached your Feb 22 invoice
#
#
#
# Outstanding payment for invoice P3902
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 10 January 2022 10:39
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
# Please find attached your Jan 22 invoice
#
#
#
# Outstanding payment for invoice P3823
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Permits Department
# Sent: 07 December 2021 20:35
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>; purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
# @purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk>
#
#
#
# Please find attached your Dec 21 invoice
#
#
#
# Outstanding payment for invoice P3741
#
#
# Kind Regards
#
# Darren Ambrose
#
# From: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Sent: 09 November 2021 13:37
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: Re: Bradford Leisure Exchange Car Park Passes
#
# [EXTERNAL]
# Hi Darren
#
# A payment was made yesterday for £1404.00. Please see attached remittance.
# The invoice that has been printed today, P3741, will be paid next month as your account has 30 day payment terms.
# Please can all invoices be sent to purchase.ledger@evo-group.co.uk<mailto:purchase.ledger@evo-group.co.uk> to make sure we have a copy as soon as possible.
#
# Thanks
# Jess
# ________________________________
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 09 November 2021 1:21 PM
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
# Attention: This email originated outside of our organisation. Please be extra vigilant when opening attachments or clicking links.
#
# Good afternoon
#
#
#
# I have not had a response to my emails below regarding your outstanding payments
#
#
#
# If someone can get back to me today or we will be left with no choice but to suspend all parking passes
#
#
#
# Outstanding payments for invoices P3567, P3660 and todays invoice P3741
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk/>
# Permits Department​
# Horizon Parking Limited
# P:
# 01245 392 289<tel:01245%20392%20289>
# E:
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#  |
# W:
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
# A:
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
# From: Permits Department
# Sent: 02 November 2021 09:19
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Morning
#
#
#
# Can I get a response to my emails below please, are the parking passes still required?
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# From: Permits Department
# Sent: 26 October 2021 08:43
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Morning,
#
#
#
# We seem to have to chase for payment each month, can you advise when the outstanding invoices will be settled please?
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# From: Permits Department
# Sent: 12 October 2021 10:08
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Good morning Richard
#
#
#
# Please find attached your Oct 21 invoice
#
#
#
# Outstanding payment for invoice P3567
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# From: Permits Department
# Sent: 08 September 2021 09:55
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good morning Richard
#
#
#
# Please find attached your Sept 21 invoice.
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# From: Permits Department
# Sent: 20 August 2021 11:23
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Morning,
#
#
#
# We have chased payment for the attached invoices a few times now, can the outstanding payments be settled as a matter of urgency,
#
#
#
# If the parking spaces are no longer needed please let us know.
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose
#
#
#
# From: Permits Department
# Sent: 13 August 2021 15:34
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Afternoon
#
#
#
# Can we have some feedback on the below email please as we still have not received payment
#
#
#
# Kind Regards
#
#
#
#
#
# From: Permits Department
# Sent: 09 August 2021 11:34
# To: 'Matt Hales' <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; 'Jessica Waring' <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: 'Richard Thaxter' <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good morning Richard
#
#
#
# Please find attached your Aug 21 invoice, with the recent new passes added this brings your allocation to x20 passes.
#
#
#
# Outstanding payment for invoice P3414.
#
#
#
#
#
# Kind Regards
#
#
#
#
#
# From: Permits Department
# Sent: 08 July 2021 11:45
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Good morning Richard
#
#
#
# Please find attached your July 21 invoice, with the recent new passes added this brings your allocation to x20 passes.
#
#
#
# Outstanding payment for invoice P3349.
#
#
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Permits Department
# Sent: 23 June 2021 09:21
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>; Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Morning,
#
#
#
# We have this morning received payment for invoice P3281 which was to cover the month of May,
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>
# Sent: 16 June 2021 13:25
# To: Jessica Waring <Jessica.Waring@evo-group.co.uk<mailto:Jessica.Waring@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# [EXTERNAL]
#
# Hi Jess
#
#
#
# Please can you look into?
#
#
#
# Cheers
#
# Matt
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 16 June 2021 13:09
# To: Matt Hales <Matt.Hales@evo-group.co.uk<mailto:Matt.Hales@evo-group.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Hi Matt,
#
#
#
# Please can you advise when invoice number P3281 will be paid?
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image003.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 16 June 2021 12:56
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Hi Richard
#
#
#
# Can you please advise regarding the outstanding payments attached
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk/>
#
# Permits Department​
#
# Horizon Parking Limited
#
# P:
#
# 01245 392 289<tel:01245%20392%20289>
#
# E:
#
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Permits Department
# Sent: 07 June 2021 11:08
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good morning Richard
#
#
#
# Please find attached your June 21 invoice.
#
#
#
# Outstanding payment for invoice P3281 please advise if the spaces are still required?
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Permits Department
# Sent: 04 June 2021 10:06
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Good Morning Richard
#
#
#
# Please be advised that the attached invoice is showing unpaid.
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Permits Department
# Sent: 11 May 2021 10:21
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Good morning
#
#
#
# Please find attached your May 21 invoice.
#
#
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Permits Department
# Sent: 12 April 2021 12:47
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Hi Richard,
#
#
#
# We still have March invoice showing as unpaid (P3139) and invoice for April (P3205)
#
#
#
# The additional 1 below will bring your allocation to 17 passes, this will be shown on your May invoice
#
#
#
# @Car Park<mailto:carpark@leisureexchange.net> do you have a list of pass numbers you have issued to Richard?
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 12 April 2021 12:29
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
#
#
#
# [EXTERNAL]
#
# Hi Steve,
#
#
#
# Please can I order an additional Pass as detailed below again to become active on 26th April 2021.
#
#
#
# Neil Grainger – Reg No YH17 EZA.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image005.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
#
#
# From: Richard Thaxter
# Sent: 09 April 2021 16:47
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Subject: FW: Bradford Leisure Exchange Car Park Passes
#
#
#
# HI Steve,
#
#
#
# Please can we order an additional 8 passes to become active on 26th April.
#
#
#
# These are :
#
#
#
# LISA KEDZIERSKI                                                          SB60 KRZ
#
# ANNA GALLONE                                                          YH59 XHA
#
# ANNEY JENNINGS                                                       YC69 TWL
#
# CHERYL ASHTON                                                         MT62 VLY
#
# JULIE WARD                                                                 YY15  MBO
#
# JO WILD                                                                        D6     JOW
#
# MAGGIE LAWRYNOWYCZ                                  ML05 OUL
#
# JADE FLOWERS                                                            J44 XDY
#
#
#
# In order to avoid separate billing if helpful you could count this as ½ month passes and charge for 4 additional passes for the full month and then 8 additional passes next month?
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image006.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
# From: Richard Thaxter
# Sent: 08 April 2021 14:09
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Hi Steve,
#
#
#
# Sorry to mess you about, but its an every changing picture here.  Just to clarify we need a further 2 passes for Monday.
#
#
#
# These are :
#
#
#
# Dawn Brown – EA61 NKJ
#
# Abbey Lawrence EO12 HVP
#
#
#
#
#
# We are happy to collect these from the ticket office at the exchange if that’s ok ? Please let me know when they will be ready.
#
#
#
# We will need a further 6 passes but not sure it will be April now. So please bill us for 8 and if we add more these can run in May.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image007.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 08 April 2021 13:23
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Car Park <carpark@leisureexchange.net<mailto:carpark@leisureexchange.net>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Hi Richard,
#
#
#
# Just for clarity we will need to know if you require the total of 14 or 15 permits before invoicing for this month.
#
#
#
# @Car Park<mailto:carpark@leisureexchange.net> apologies, there has been an increase in the number of passes to a potential 9, Richard will confirm. Will be these be delivered or will they need to be picked up?
#
#
#
# Kind Regards
#
#
#
# Steven McNeill
#
#
#
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk/>
#
# Permits Department​
#
# Horizon Parking Limited
#
# P:
#
# 01245 392 289<tel:01245%20392%20289>
#
# E:
#
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 08 April 2021 13:20
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# [EXTERNAL]
#
# Hi Steven,
#
#
#
# Yes that’s right, we will have more required in May.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image009.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 08 April 2021 13:18
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Hi Richard,
#
#
#
# So an additional 8 or 9 in total and not as well as the additional 6?
#
#
#
# Once the numbers are confirmed we will produce the invoice and organise passes.
#
#
#
# Kind Regards
#
#
#
# Steven McNeill
#
#
#
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk/>
#
# Permits Department​
#
# Horizon Parking Limited
#
# P:
#
# 01245 392 289<tel:01245%20392%20289>
#
# E:
#
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 08 April 2021 13:15
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# [EXTERNAL]
#
# Good afternoon,
#
#
#
# I will pass on the invoice for March for payment. With regards to April, we have 8 or 9 additional passes required. I will forward you details today so the passes can be produced for Monday.
#
#
#
# Please can I ask that the April invoice is amended to reflect the new numbers of passes required.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image011.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 08 April 2021 12:43
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Service Invoice Approval <serviceinvoiceapproval@evo-group.co.uk<mailto:serviceinvoiceapproval@evo-group.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# Good afternoon
#
#
#
# Please find attached your April 21 invoice.
#
#
#
# Outstanding payment for Invoice P3139
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
#
#
# [Horizon Parking Limited]<http://www.horizonparking.co.uk/>
#
# Permits Department​
#
# Horizon Parking Limited
#
# P:
#
# 01245 392 289<tel:01245%20392%20289>
#
# E:
#
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Permits Department
# Sent: 15 March 2021 09:30
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Service Invoice Approval <serviceinvoiceapproval@evo-group.co.uk<mailto:serviceinvoiceapproval@evo-group.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
# Importance: High
#
#
#
# Hi Richard,
#
#
#
# We still have the attached invoices showing as unpaid, can you advise when the payment run will be for these?
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 05 March 2021 12:11
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Service Invoice Approval <serviceinvoiceapproval@evo-group.co.uk<mailto:serviceinvoiceapproval@evo-group.co.uk>>
# Subject: RE: Bradford Leisure Exchange Car Park Passes
#
#
#
# [EXTERNAL]
#
# HI Darren,
#
#
#
# Many thanks for the message.
#
#
#
# Yes the Spaces are required, we are likely to need to up the number as staff return after Easter.
#
#
#
# There is a chance we may need more spaces too, as other staff will be re-locating to Bradford over the next 2-3 month.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext 6068  | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
# [newspeclogo]A Banner Group Company
#
#
#
# [cid:image013.png@01D8AB0F.1647C110]<https://www.easyflip.co.uk/Banner2021CatalogueUnpriced/>
#
#
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 05 March 2021 12:03
# ...
# Sent: 20 April 2020 08:30
# To: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Craig Varey <Craig.Varey@banneruk.com<mailto:Craig.Varey@banneruk.com>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: FW: Bradford Leisure Excchange Car Park Passes
# Importance: High
#
#
#
# [EXTERNAL]
#
# Hi Darren,
#
#
#
# Thank you for your message. I will forward this on to our Accounts Payable dept for their input.
#
#
#
# I am sure you will appreciate these are very difficult time for us all, our Bradford Offices have been closed for a month and are likely to be closed for at least another 3 weeks, so although we have passes we are not using them. Please can I therefore ask if you are able to provide us some relief on charges until we are able to return to work as normal.
#
#
#
# Regards
#
#
#
# Richard Thaxter
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 308188 Ext: 6068 | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
#
#
#
#
#
#
#
#
# From: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Sent: 18 April 2020 20:54
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Craig Varey <Craig.Varey@banneruk.com<mailto:Craig.Varey@banneruk.com>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
# Importance: High
#
#
#
# Hi Richard
#
#
#
# Following on from the below email please be advised the attached invoice is showing unpaid, please advise when this will be settled?
#
#
#
# Kind Regards
#
#
#
# Darren
#
#
#
#
#
# <image006.jpg><http://www.horizonparking.co.uk/>
#
#
#
# Permits Department​
#
# Horizon Parking Limited
#
# P:
#
# 01245 392 289<tel:01245%20392%20289>
#
# E:
#
# permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Permits Department
# Sent: 06 March 2020 15:11
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>; Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>
# Cc: Craig Varey <Craig.Varey@banneruk.com<mailto:Craig.Varey@banneruk.com>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Good Afternoon Richard,
#
#
#
# @Monjur Ahmed<mailto:monjur.ahmed@horizonparking.co.uk> will be able to answer your question regarding the passes,
#
#
#
# Please find your invoice attached.
#
#
#
# Kind Regards
#
#
#
# Darren Ambrose.
#
#
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 06 March 2020 14:09
# To: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Cc: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Craig Varey <Craig.Varey@banneruk.com<mailto:Craig.Varey@banneruk.com>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Good afternoon  Monjur/Myles,
#
#
#
# Please find attached the signed Contract as requested.
#
#
#
# Please can you confirm this afternoon that we can use the car park from Monday 9th March. Our staff arrive from 6.30am ?
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 767721 | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
# From 17.2.2020 T: 01274 308188 Ext: 6068
#
# <image007.jpg>
#
#
#
#
#
#
#
#
#
# From: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Sent: 06 March 2020 12:52
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Cc: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Afternoon Richard,
#
#
#
# I hope all is well.
#
#
#
# My colleague Myles is away today so im picking this up in his absence.
#
#
#
# Please find attached you amended agreement for 18 spaces, please read through sign and send back. As soon as I have it back I can pass you over to my accounts team for invoicing.
#
#
#
# Any issues, give me a shout.
#
#
#
# Thanks,
#
#
#
# Jack C
#
#
#
#
#
# <image008.jpg><http://www.horizonparking.co.uk/>
#
#
#
# Spaces​
#
# Horizon Parking Limited
#
# E:
#
# spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 05 March 2020 13:18
# To: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Cc: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Good Afternoon Myles,
#
#
#
# Apologies for the delay in getting back to you.
#
#
#
# We have now been through the Licence and would like the following changes to be made:
#
#
#
#   1.  Please can we increase the number of Car Parking spaces from 16 to 18.
#   2.  The licence fee will therefore increase to £526.50 per month or £6,318 + VAT pa.
#   3.  We would like to start from Monday 9th March.
#
#
#
# If you can send an amended licence today I will return this signed for you.
#
#
#
# Please can you then advise how we obtain passes, ideally we would like to obtain these tomorrow so our staff have them for Monday, can we achieve this?
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 767721 | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
# From 17.2.2020 T: 01274 308188 Ext: 6068
#
# <image009.jpg>
#
#
#
#
#
#
#
#
#
# From: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Sent: 25 February 2020 17:16
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Cc: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>; Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Afternoon Richard,
#
#
#
# Please find our Licence agreement attached.
#
#
#
# If you could review, sign and return we can then have our permit team set up an monthly invoice for you.
#
#
#
# Any issues with the agreement, please do let us know so Monjur and I can advise accordingly.
#
#
#
# Kind Regards
#
#
#
# Myles
#
#
#
#
#
# <image010.jpg><http://www.horizonparking.co.uk/>
#
#
#
# Spaces​
#
# Horizon Parking Limited
#
# E:
#
# spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 25 February 2020 13:44
# To: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>; Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Hi Myles,
#
#
#
# The full company name and address for the licence is
#
#
#
# Banner Group Ltd,
#
# K House
#
# Europa Link
#
# Sheffield S9 1XU
#
#
#
# We look forward to receiving the licence.
#
#
#
# Regards
#
#
#
# Richard
#
#
#
# Richard Thaxter | Sales Director | Spectrum
# T: 01274 767721 | M 07713 499911 | E richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>
#
# From 17.2.2020 T: 01274 308188 Ext: 6068
#
# <image007.jpg>
#
#
#
#
#
#
#
#
#
# From: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Sent: 25 February 2020 11:08
# To: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>; Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Morning Richard,
#
#
#
# Could you kindly provide the company full name and address which will be detailed on the licence agreement.
#
#
#
# Once provided we will amend and send across for your review.
#
#
#
# Kind Regards
#
#
#
# Myles
#
#
#
#
#
# <image008.jpg><http://www.horizonparking.co.uk/>
#
#
#
# Spaces​
#
# Horizon Parking Limited
#
# E:
#
# spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>
# Sent: 25 February 2020 09:57
# To: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>; Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>
# Cc: Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Subject: RE: Bradford Leisure Excchange Car Park Passes
#
#
#
# Hi Richard
#
#
#
# Sorry yes, you did say that to me.
#
#
#
# @Permits Department<mailto:permits@horizonparking.co.uk>can you please set up at the same rate for 16 passes please.
#
#
#
# Thanks
#
#
#
# Regards
#
#
#
#
#
#
#
#
#
# <image003.jpg><http://www.horizonparking.co.uk/>
#
#
#
# Monjur Ahmed​
#
# Client Relationship Manager
#
# ,
#
# Horizon Parking Limited
#
# M:
#
# 07511 610 549<tel:07511%20610%20549>
#
# E:
#
# monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# From: Richard Thaxter <richardthaxter@spectrumltd.co.uk<mailto:richardthaxter@spectrumltd.co.uk>>
# Sent: 25 February 2020 09:56
# To: Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>>
# Cc: Permits Department <permits@horizonparking.co.uk<mailto:permits@horizonparking.co.uk>>; Spaces <spaces@horizonparking.co.uk<mailto:spaces@horizonparking.co.uk>>
# Subject: Re: Bradford Leisure Excchange Car Park Passes
#
#
#
# Hi Monjur,
#
#
#
# We initially require 16 passes this will increase to 25 very soon. Please can you set up the agreement on this basis. I assume the passes will be at the same cost as agreed.
#
#
#
# Regards
#
# Richard
#
# Sent from my iPhone
#
#
#
# On 25 Feb 2020, at 09:31, Monjur Ahmed <monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>> wrote:
#
# ﻿
#
# Good morning Richard
#
#
#
# I hope all is well.
#
#
#
# As discussed yesterday we will set up an agreement with your company for us to provide annual car park passes for your staff members at the Bradford Leisure Exchange.  You have requested 25 passes initially, potentially increasing that number to 30 in the future.
#
#
#
# The current annual price per pass is £390, however I am happy to put a 10% discount in place and further look at the discount structure as and when you increase your numbers to 30+.
#
#
#
# Therefore the total cost for 25 passes @ £390 each – 10% = £8775.  You have requested to pay the invoice monthly which is absolutely fine, I have copied my colleagues into this email who will liaise with you to finalise all the paperwork and internal processes.  Once that is done our car park office staff will create your passes ready for collection directly form site.
#
#
#
# If you have any questions or need further help or assistance please don’t hesitate to contact me, for now I shall leave you in the capable hands of my colleagues.
#
#
#
# Many thanks
#
#
#
# Regards
#
#
#
#
#
#
#
#
#
#
#
# <image755000.jpg><http://www.horizonparking.co.uk>
#
#
#
# Monjur Ahmed​
#
# Client Relationship Manager
#
# ,
#
# Horizon Parking Limited
#
# M:
#
# 07511 610 549<tel:07511%20610%20549>
#
# E:
#
# monjur.ahmed@horizonparking.co.uk<mailto:monjur.ahmed@horizonparking.co.uk>
#
#  |
#
# W:
#
# www.horizonparking.co.uk<http://www.horizonparking.co.uk>
#
# A:
#
# Finitor House, 2 Hanbury Road, Chelmsford, Essex, CM1 3AE<https://www.google.com/maps/place/Horizon+Parking/@51.7257024,0.4474682,18.5z/data=!4m5!3m4!1s0x47d8ebc97de1b2f3:0x1b7e9e3799e0d0be!8m2!3d51.7256895!4d0.4482957>
#
# CONFIDENTIALITY NOTICE: This email communication may contain private, confidential, or legally privileged information intended for the sole use of the designated and/or duly authorised recipient(s). If you are not the intended recipient or have received this email in error, please notify the sender immediately by email and permanently delete all copies of this email including all attachments without reading them.
#
#
#
# <Invoice P2602.pdf>
